# %% [markdown]
# # Trabajo Final de "PROGRAMACIÓN 1" - TUIA - 2C - 2023
# # Integrantes del Grupo:
# *   XXXX, XXXXX
# *   XXXX, XXXXX
# *   XXXX, XXXXX
# *   XXXX, XXXXX

# %%
#! pip3 install matplotlib.pyplot
!# pip3 install seaborn

# %%
#import matplotlib.pyplot as plt
#import seaborn as sns

# %% [markdown]
# # Presentación del tema: **Servicio Meteorológico**
#
# El **Servicio Meteorológico Nacional** publica diferentes mediciones que se realizan de temperaturas, viento, humedad, precipitaciones, etc. en diferentes lugares del país en la [web](https://datos.gob.ar/dataset?groups=envi&organization=defensa&_tags_limit=0).
#
#
# En el presente trabajo vamos a utilizar los datos publicados sobre [mediciones](https://drive.google.com/file/d/1HcjvyLIbMNk4GceqhLDcUkg--Rv0vpOU/view?usp=sharing) efectuadas en diferentes
# puntos del país en el último año.

# %% [markdown]
# # Estructura de datos
#
# Para la resolución del presente trabajo debe usar alguna de las estructuras de datos vistas en la materia:
#
# *   Listas
# *   Diccionarios
# *   Tuplas
# *   Clases y Objetos
#
# o una combinación de ellas.

# %% [markdown]
# # Carga de datos en las estructuras
#
# En grupo, analicen el contenido del archivo *servicio_meteorológico.csv* que provee ciertas mediciones efectuadas en diferentes estaciones meteorológicas del país.
#
# *Para la implementación de este trabajo final, recuerden que es muy importante comentar el código, usar nombres de variables significativos y definir funciones para trabajar de manera modular.*

# %%
#Las siguientes líneas de código son necesarias para poder trabajar con archivos .csv y realizar gráficos
import csv
#import matplotlib.pyplot as plt
#import seaborn as sns
#sns.set()

# %% [markdown]
# NOTA: en clase se explicará cómo trabajar con archivos .csv y cargar datos en alguna de las estructuras de datos vistas durante la materia. Luego, en grupo, deberán analizar cuáles son las estructuras de datos más convenientes según las preguntas que deban responder más adelante. Completaremos el enunciado en las próximas semanas. Mientras tanto, analicen los datos del archivo compartido y practiquen la lectura de datos desde archivos implementando una o varias funciones carga (para las distintas estructuras de datos que propongan).

# %%
def openFile(*args) -> list:
    """
    Recibe un archivo de tipo csv y devuelve dos listas, una los datos de cada estación de observación meteorológica y otra el encabezado.
    """
    with open(*args, "r", encoding="macintosh") as contenido:
        lector = csv.reader(contenido)
        lista_retorno = []
        encabezado = next(lector)
        for fila in lector:
            for elemento in fila:
                lista_retorno.append(elemento)

    return lista_retorno, encabezado

# %%
#definan una o varias funciones para imprimir la información cargada
#reemplace el nombre imprimir_xxx por un nombre adecuado
def imprimir_xxx() -> None: #completar el tipo de parámetro
	#toma como parámetro una estructura de datos y muestra
	#en pantalla su contenido de manera elegante

  #completar
    pass
#usen esta(s) función(es) para chequear que la función carga hace lo que se espera

# %% [markdown]
# # Funciones
#
#
# 1.   Crear UNA función que sirva para calcular el promedio, el máximo y el mínimo anual de cada medida, asumiendo que todos los datos están completos y son correctos.
# 2.   Modifique la función anterior, sabiendo que no se disponen de todas las mediciones. Aquellas mediciones faltantes se indentifican con 'S/D' y no deben ser tenidas en cuenta para los cálculos.

# %%
def medidasTendencia(lista_retorno: list, encabezado: list) -> list:
    cant_columnas = 14
    columna = []
    suma = 0
    for elemento in lista_retorno:
        columna.append(elemento)
        if len(columna) == cant_columnas:
            print(columna)
            lista = []            
            for elemento_interno in range(len(columna)):                
                try:
                    columna[elemento_interno] = float(columna[elemento_interno])                    
                    suma += columna[elemento_interno]
                    promedio = suma / 12
                    lista.append(columna[elemento_interno])                        
                    maximo = max(lista)
                    minimo = min(lista)
                except:
                    print("Valor salteado")
                    continue
            print("El promedio es de: ", promedio, "El máximo es de: ", maximo, "El mínimo es de: ", minimo, ".")
            columna = []
        suma = 0
           
    return

# %% [markdown]
# ## Objetos
#
#
# 1. Cree una clase llamada `EstacionMeteorologica` que represente una estación meteorológica. La clase debe tener como atributos de instancia los datos correspondientes a:
# * nombre de la estacion (nombre_estacion)
# * temperaturas promedios para cada mes del año (temps_prom_mens)
# * temperatura maxima anual (temp_maxima)
# * temperatura minima anual (temp_minima)
# * humedad anual promedio (hum_promedio)
# * humedad maxima anual (hum_maxima)
# * humedad minima anual (hum_minima)
# * velocidad promedio anual (vel_promedio)
# * velocidad maxima anual (vel_maxima)
# * velocidad minima anual (vel_minima)
#
#
# 2.   Implemente el método **\_\_init\_\_** y **\_\_str\_\_**.
# # Objetos
#
#
# 1. Cree una clase llamada **EstacionMeteorologica** que represente una estación meteorológica. La clase debe tener como atributos de instancia los datos correspondientes a:
#   * nombre de la estacion (**nombre_estacion**)
#   * temperaturas promedios para cada mes del año (**temps_prom_mens**)
#   * temperatura maxima anual (**temp_maxima**)
#   * temperatura minima anual (**temp_minima**)
#   * humedad anual promedio (**hum_promedio**)
#   * humedad maxima anual (**hum_maxima**)
#   * humedad minima anual (**hum_minima**)
#   * velocidad promedio anual (**vel_promedio**)
#   * velocidad maxima anual (**vel_maxima**)
#   * velocidad minima anual (**vel_minima**)
#
# 2. Implemente el método **\_\_init\_\_** y **\_\_str\_\_**.
#
#
# 3. Implemente los siguientes métodos en la clase **EstacionMeteorologica**:
#
#   3.1  Un método **promedio_temp_anual** que calcule el promedio de temperatura anual para la estación
#
#   3.1. Un método **comparar_con** que reciba otra estación como parámetro y retorne una comparación mes a mes de las temperaturas promedio entre las dos estaciones.
#
#   3.2. Un método **graficar_temperaturas** que grafique la evolución de las temperaturas en la estación a lo largo del año

# %%
class EstacionMeteorologica:
    """
    Esta clase representa una estación meteorológica,
    contiene los datos relevantes al análisis.
    """
    def __init__(self, nombre_estacion, temps_prom_mens, temp_maxima, temp_minima,
                 hum_promedio, hum_maxima, hum_minima, vel_promedio, vel_maxima, vel_minima):
        self.nombre_estacion = nombre_estacion
        self.temps_prom_mens = temps_prom_mens
        self.temp_maxima = temp_maxima
        self.temp_minima = temp_minima
        self.hum_promedio = hum_promedio
        self.hum_maxima = hum_maxima
        self.hum_minima = hum_minima
        self.vel_promedio = vel_promedio
        self.vel_maxima = vel_maxima
        self.vel_minima = vel_minima

    def __str__(self):
        return f"El presente objeto representa a la estación meteorológica {self.nombre_estacion}. Cada estación provee información sobre {self.temps_prom_mens}, {self.temps_prom_mens}, {self.temp_maxima}, {self.temp_minima}, {self.hum_promedio}, {self.hum_maxima}, {self.hum_minima}, {self.vel_promedio}, {self.vel_maxima}, {self.vel_minima}."

# %%
def instanciaEstacion(lista_retorno: list) -> list:
    """
    La función instanciaViaje crea instancias a partir del output lista_retorno creado por la función openFile. Primero
    inicializa una variable fija de contador de cantidad de atributos totales de la clase Viaje. Luego se crea una lista
    de listas, que en su interior contiene las instancias individuales de cada Viaje. Se itera un bucle que toma los
    elementos de la lista y al igualar el número de atributos de la instancia, los atribuye a una instancia individual
    del objeto. Este objeto se añade a la lista de listas y se reinicia la lista de objetos individuales inicializándose
    vacía. Por último, retorna una lista que contiene todas las instancias de Viaje.
    """
    nro_de_atributos_instancia = 14
    instancia = []
    instancia_de_estaciones = []

    for elemento in lista_retorno:
        instancia.append(elemento)
        if len(instancia) == nro_de_atributos_instancia:
            estacion = EstacionMeteorológica(instancia[0], instancia[1], instancia[2], int(instancia[3]), int(instancia[4]), instancia[5])
            instancia_de_viajes.append(estacion)
            instancia = []
    print("Se crearon ", len(instancia_de_estaciones), "instancias de estaciones")
    return instancia_de_viajes

# %%
estaciones, encabezado = openFile("servicio_meteorologico.csv")

#print(estaciones)

medidasTendencia(estaciones, encabezado)
# Out:
# ['LA QUIACA OBS.', 'Temperatura (grados C)', '12.8', '12.5', '12.4', '10.9', '6.9', '4.4', '4.1', '6.7', '9.3', '11.7', '12.8', '13.2']
# Valor salteado
# Valor salteado
# El promedio es de:  9.808333333333334 El máximo es de:  13.2 El mínimo es de:  4.1 .
# ['LA QUIACA OBS.', 'Temperatura máxima (grados C)', '20.1', '19.9', '19.9', '19.7', '17.3', '15.6', '15.4', '17.4', '19.2', '21.1', '21.7', '21.3']
# Valor salteado
# Valor salteado
# El promedio es de:  19.049999999999997 El máximo es de:  21.7 El mínimo es de:  15.4 .
# ['LA QUIACA OBS.', 'Temperatura mínima (grados C)', '7.4', '7.0', '6.3', '2.8', '-3.0', '-6.2', '-6.8', '-4.2', '-1.1', '2.8', '5.2', '6.9']
# Valor salteado
# Valor salteado
# El promedio es de:  1.425 El máximo es de:  7.4 El mínimo es de:  -6.8 .
# ['LA QUIACA OBS.', 'Humedad relativa (%)', '65.3', '64.1', '62.4', '48.2', '34.6', '31.1', '30.1', '31.7', '34.4', '45.3', '52.3', '59.2']
# Valor salteado
# Valor salteado
# El promedio es de:  46.55833333333334 El máximo es de:  65.3 El mínimo es de:  30.1 .
# ['LA QUIACA OBS.', 'Velocidad del Viento (km/h)', '6.9', '7.1', '6.5', '6.4', '6.0', '4.9', '6.6', '6.6', '8.6', '8.7', '8.8', '8.3']
# Valor salteado
# Valor salteado
# El promedio es de:  7.116666666666666 El máximo es de:  8.8 El mínimo es de:  4.9 .
# ['LA QUIACA OBS.', 'Nubosidad total (octavos)', '5.2', '4.8', '4.1', '2.7', '1.8', '1.6', '1.4', '1.6', '2.0', '3.0', '3.6', '4.5']
# Valor salteado
# Valor salteado
# El promedio es de:  3.0250000000000004 El máximo es de:  5.2 El mínimo es de:  1.4 .
# ['LA QUIACA OBS.', 'Precipitación (mm)', '97.5', '68.4', '55.9', '8.2', '1.0', '0.5', '0.0', '1.4', '3.5', '16.0', '27.3', '71.9']
# Valor salteado
# Valor salteado
# El promedio es de:  29.3 El máximo es de:  97.5 El mínimo es de:  0.0 .
# ['LA QUIACA OBS.', 'Frecuencia de días con Precipitación superior a 0.1 mm', '15.9', '12.2', '9.8', '2.4', '0.3', '0.1', '0.0', '0.4', '0.9', '3.5', '7.4', '12.7']
# Valor salteado
# Valor salteado
# El promedio es de:  5.466666666666666 El máximo es de:  15.9 El mínimo es de:  0.0 .
# ['TARTAGAL AERO', 'Temperatura (grados C)', '25.2', '24.4', 'S/D', '20.2', '17.2', '14.9', '14.6', '17.4', '20.2', '23.9', '24.6', '25.3']
# Valor salteado
# Valor salteado
# Valor salteado
# El promedio es de:  18.991666666666667 El máximo es de:  25.3 El mínimo es de:  14.6 .
# ['TARTAGAL AERO', 'Temperatura máxima (grados C)', '31.7', '30.7', '29.1', '25.5', '22.7', '21.0', '22.1', '25.5', '28.2', '31.4', '31.7', '32.0']
# Valor salteado
# Valor salteado
# El promedio es de:  27.63333333333333 El máximo es de:  32.0 El mínimo es de:  21.0 .
# ['TARTAGAL AERO', 'Temperatura mínima (grados C)', '20.6', '20.0', '19.6', '17.0', '13.2', '10.7', '9.1', '10.6', '13.2', '17.5', '18.8', '20.3']
# Valor salteado
# Valor salteado
# El promedio es de:  15.883333333333335 El máximo es de:  20.6 El mínimo es de:  9.1 .
# ['TARTAGAL AERO', 'Humedad relativa (%)', '78.5', 'S/D', 'S/D', '85.0', '83.5', '80.8', '71.9', '62.0', '55.1', '60.1', '67.1', '74.4']
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# El promedio es de:  59.866666666666674 El máximo es de:  85.0 El mínimo es de:  55.1 .
# ['TARTAGAL AERO', 'Velocidad del Viento (km/h)', '6.1', '5.9', '5.2', '4.7', '4.6', '4.6', '5.6', '6.7', '7.3', '8.1', '8.6', '7.1']
# Valor salteado
# Valor salteado
# El promedio es de:  6.208333333333333 El máximo es de:  8.6 El mínimo es de:  4.6 .
# ['TARTAGAL AERO', 'Nubosidad total (octavos)', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D']
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# El promedio es de:  6.208333333333333 El máximo es de:  8.6 El mínimo es de:  4.6 .
# ['TARTAGAL AERO', 'Precipitación (mm)', '200.2', '182.8', '187.7', '65.3', '22.0', '6.7', '3.6', '5.1', '15.1', '45.0', '110.0', '176.4']
# Valor salteado
# Valor salteado
# El promedio es de:  84.99166666666667 El máximo es de:  200.2 El mínimo es de:  3.6 .
# ['TARTAGAL AERO', 'Frecuencia de días con Precipitación superior a 0.1 mm', '11.6', '11.1', '11.7', '10.5', '5.9', '3.6', '2.2', '1.7', '2.4', '5.1', '9.0', '11.4']
# Valor salteado
# Valor salteado
# El promedio es de:  7.183333333333334 El máximo es de:  11.7 El mínimo es de:  1.7 .
# ['JUJUY AERO', 'Temperatura (grados C)', '23.6', '22.5', '21.4', '18.3', '14.8', '12.2', '11.9', '15.0', '17.8', '21.7', '23.0', '23.8']
# Valor salteado
# Valor salteado
# El promedio es de:  18.833333333333332 El máximo es de:  23.8 El mínimo es de:  11.9 .
# ['JUJUY AERO', 'Temperatura máxima (grados C)', '30.0', '28.8', '27.2', '24.0', '21.3', '19.7', '20.3', '23.3', '25.7', '29.0', '29.9', '30.5']
# Valor salteado
# Valor salteado
# El promedio es de:  25.808333333333334 El máximo es de:  30.5 El mínimo es de:  19.7 .
# ['JUJUY AERO', 'Temperatura mínima (grados C)', '18.3', '17.5', '17.1', '14.0', '10.0', '6.8', '5.8', '8.2', '10.6', '14.8', '16.7', '18.0']
# Valor salteado
# Valor salteado
# El promedio es de:  13.149999999999999 El máximo es de:  18.3 El mínimo es de:  5.8 .
# ['JUJUY AERO', 'Humedad relativa (%)', '74.4', '77.7', '82.0', '82.4', '79.7', '76.7', '68.0', '58.7', '52.3', '56.0', '62.0', '68.8']
# Valor salteado
# Valor salteado
# El promedio es de:  69.89166666666667 El máximo es de:  82.4 El mínimo es de:  52.3 .
# ['JUJUY AERO', 'Velocidad del Viento (km/h)', '8.2', '8.3', '7.3', '7.1', '7.4', '7.3', '9.2', '10.3', '11.0', '10.7', '10.2', '8.9']
# Valor salteado
# Valor salteado
# El promedio es de:  8.825000000000001 El máximo es de:  11.0 El mínimo es de:  7.1 .
# ['JUJUY AERO', 'Nubosidad total (octavos)', '5.3', '5.2', '5.4', '5.3', '4.7', '4.1', '3.2', '3.1', '3.4', '4.1', '4.5', '5.0']
# Valor salteado
# Valor salteado
# El promedio es de:  4.441666666666667 El máximo es de:  5.4 El mínimo es de:  3.1 .
# ['JUJUY AERO', 'Precipitación (mm)', '153.2', '152.9', '138.9', '49.4', '11.6', '2.8', '3.4', '3.1', '5.4', '28.1', '61.1', '130.4']
# Valor salteado
# Valor salteado
# El promedio es de:  61.69166666666667 El máximo es de:  153.2 El mínimo es de:  2.8 .
# ['JUJUY AERO', 'Frecuencia de días con Precipitación superior a 0.1 mm', '13.4', '12.5', '14.1', '8.7', '3.9', '2.0', '2.3', '1.6', '1.9', '4.8', '7.8', '11.6']
# Valor salteado
# Valor salteado
# El promedio es de:  7.05 El máximo es de:  14.1 El mínimo es de:  1.6 .
# ['SALTA AERO', 'Temperatura (grados C)', '21.4', '20.3', '19.5', '16.6', '13.1', '10.6', '10.1', '12.7', '15.1', '19.1', '20.5', '21.5']
# Valor salteado
# Valor salteado
# El promedio es de:  16.708333333333332 El máximo es de:  21.5 El mínimo es de:  10.1 .
# ['SALTA AERO', 'Temperatura máxima (grados C)', '27.4', '26.4', '25.2', '22.7', '20.3', '19.6', '20.0', '22.3', '23.9', '26.8', '27.5', '28.0']
# Valor salteado
# Valor salteado
# El promedio es de:  24.175 El máximo es de:  28.0 El mínimo es de:  19.6 .
# ['SALTA AERO', 'Temperatura mínima (grados C)', '16.6', '15.7', '15.3', '11.9', '7.6', '4.1', '2.9', '4.9', '7.3', '11.8', '14.1', '15.9']
# Valor salteado
# Valor salteado
# El promedio es de:  10.674999999999999 El máximo es de:  16.6 El mínimo es de:  2.9 .
# ['SALTA AERO', 'Humedad relativa (%)', '78.2', '81.0', '83.7', '82.9', '80.5', '75.5', '69.1', '62.8', '58.2', '61.2', '67.1', '73.1']
# Valor salteado
# Valor salteado
# El promedio es de:  72.775 El máximo es de:  83.7 El mínimo es de:  58.2 .
# ['SALTA AERO', 'Velocidad del Viento (km/h)', '6.8', '6.5', '5.8', '5.8', '6.3', '6.1', '6.9', '7.5', '7.9', '9.0', '8.7', '7.7']
# Valor salteado
# Valor salteado
# El promedio es de:  7.083333333333333 El máximo es de:  9.0 El mínimo es de:  5.8 .
# ['SALTA AERO', 'Nubosidad total (octavos)', '5.9', '5.8', '5.9', '5.6', '5.0', '4.2', '3.3', '3.2', '3.5', '4.4', '5.0', '5.5']
# Valor salteado
# Valor salteado
# El promedio es de:  4.775 El máximo es de:  5.9 El mínimo es de:  3.2 .
# ['SALTA AERO', 'Precipitación (mm)', '192.6', '154.2', '110.6', '33.0', '8.0', '1.5', '3.9', '3.8', '7.6', '25.1', '62.2', '145.6']
# Valor salteado
# Valor salteado
# El promedio es de:  62.34166666666667 El máximo es de:  192.6 El mínimo es de:  1.5 .
# ['SALTA AERO', 'Frecuencia de días con Precipitación superior a 0.1 mm', '16.3', '14.8', '14.2', '7.9', '3.9', '1.6', '2.1', '2.1', '2.7', '5.7', '9.5', '14.0']
# Valor salteado
# Valor salteado
# El promedio es de:  7.8999999999999995 El máximo es de:  16.3 El mínimo es de:  1.6 .
# ['LAS LOMITAS', 'Temperatura (grados C)', '27.9', '26.8', '25.8', '22.5', '18.8', '16.9', '16.6', '19.1', '21.2', '24.6', '25.9', '27.3']
# Valor salteado
# Valor salteado
# El promedio es de:  22.78333333333333 El máximo es de:  27.9 El mínimo es de:  16.6 .
# ['LAS LOMITAS', 'Temperatura máxima (grados C)', '35.1', '33.8', '32.8', '28.8', '25.4', '23.4', '24.1', '27.1', '29.1', '32.2', '33.2', '34.4']
# Valor salteado
# Valor salteado
# El promedio es de:  29.95 El máximo es de:  35.1 El mínimo es de:  23.4 .
# ['LAS LOMITAS', 'Temperatura mínima (grados C)', '21.7', '21.1', '20.3', '17.5', '13.7', '11.8', '10.4', '12.2', '14.2', '17.8', '19.3', '20.9']
# Valor salteado
# Valor salteado
# El promedio es de:  16.741666666666667 El máximo es de:  21.7 El mínimo es de:  10.4 .
# ['LAS LOMITAS', 'Humedad relativa (%)', '69.3', '72.2', '75.2', '79.4', '79.9', '79.3', '71.3', '62.8', '60.5', '62.7', '65.9', '68.2']
# Valor salteado
# Valor salteado
# El promedio es de:  70.55833333333334 El máximo es de:  79.9 El mínimo es de:  60.5 .
# ['LAS LOMITAS', 'Velocidad del Viento (km/h)', '5.4', '7.0', '6.0', '5.9', '5.8', '5.3', '6.9', '8.6', '8.7', '9.4', '9.9', '8.2']
# Valor salteado
# Valor salteado
# El promedio es de:  7.258333333333334 El máximo es de:  9.9 El mínimo es de:  5.3 .
# ['LAS LOMITAS', 'Nubosidad total (octavos)', '4.0', '3.9', '3.5', '4.2', '4.1', '4.4', '3.5', '3.1', '3.5', '3.7', '3.7', '3.8']
# Valor salteado
# Valor salteado
# El promedio es de:  3.7833333333333337 El máximo es de:  4.4 El mínimo es de:  3.1 .
# ['LAS LOMITAS', 'Precipitación (mm)', '142.4', '116.7', '160.4', '84.6', '57.5', '18.6', '13.1', '16.1', '30.4', '72.5', '119.0', '132.6']
# Valor salteado
# Valor salteado
# El promedio es de:  80.325 El máximo es de:  160.4 El mínimo es de:  13.1 .
# ['LAS LOMITAS', 'Frecuencia de días con Precipitación superior a 0.1 mm', '8.8', '9.2', '9.9', '9.3', '7.1', '6.0', '3.9', '2.9', '4.4', '7.3', '8.7', '8.8']
# Valor salteado
# Valor salteado
# El promedio es de:  7.191666666666666 El máximo es de:  9.9 El mínimo es de:  2.9 .
# ['IGUAZU AERO', 'Temperatura (grados C)', '25.6', '24.9', '24.2', '21.4', '17.6', '15.9', '15.7', '17.6', '19.1', '21.9', '23.5', '25.0']
# Valor salteado
# Valor salteado
# El promedio es de:  21.03333333333333 El máximo es de:  25.6 El mínimo es de:  15.7 .
# ['IGUAZU AERO', 'Temperatura máxima (grados C)', '31.8', '31.2', '30.7', '27.5', '23.5', '21.7', '22.2', '24.7', '25.8', '28.3', '30.1', '31.4']
# Valor salteado
# Valor salteado
# El promedio es de:  27.40833333333333 El máximo es de:  31.8 El mínimo es de:  21.7 .
# ['IGUAZU AERO', 'Temperatura mínima (grados C)', '20.5', '20.2', '19.3', '16.8', '13.1', '11.7', '10.8', '12.2', '13.7', '16.5', '17.8', '19.5']
# Valor salteado
# Valor salteado
# El promedio es de:  16.008333333333333 El máximo es de:  20.5 El mínimo es de:  10.8 .
# ['IGUAZU AERO', 'Humedad relativa (%)', '78.1', '80.4', '79.7', '83.7', '86.5', '88.1', '83.6', '78.5', '76.4', '77.3', '74.9', '75.7']
# Valor salteado
# Valor salteado
# El promedio es de:  80.24166666666666 El máximo es de:  88.1 El mínimo es de:  74.9 .
# ['IGUAZU AERO', 'Velocidad del Viento (km/h)', '6.4', '6.3', '5.3', '6.1', '6.4', '6.2', '7.4', '8.4', '8.8', '7.4', '7.5', '6.6']
# Valor salteado
# Valor salteado
# El promedio es de:  6.8999999999999995 El máximo es de:  8.8 El mínimo es de:  5.3 .
# ['IGUAZU AERO', 'Nubosidad total (octavos)', '4.2', '4.3', '3.6', '3.7', '3.6', '4.0', '3.4', '3.5', '4.0', '4.1', '3.7', '3.9']
# Valor salteado
# Valor salteado
# El promedio es de:  3.8333333333333335 El máximo es de:  4.3 El mínimo es de:  3.4 .
# ['IGUAZU AERO', 'Precipitación (mm)', '177.7', '154.7', '126.5', '169.1', '192.7', '148.3', '115.8', '94.2', '160.3', '237.0', '186.3', '186.9']
# Valor salteado
# Valor salteado
# El promedio es de:  162.45833333333334 El máximo es de:  237.0 El mínimo es de:  94.2 .
# ['IGUAZU AERO', 'Frecuencia de días con Precipitación superior a 0.1 mm', '10.3', '10.2', '8.1', '8.9', '8.8', '8.6', '8.3', '6.8', '9.6', '11.6', '9.4', '9.9']
# Valor salteado
# Valor salteado
# El promedio es de:  9.208333333333334 El máximo es de:  11.6 El mínimo es de:  6.8 .
# ['TUCUMAN AERO', 'Temperatura (grados C)', '25.2', '24.0', '22.6', '19.2', '15.7', '12.7', '12.2', '14.9', '17.8', '21.8', '23.4', '24.9']
# Valor salteado
# Valor salteado
# El promedio es de:  19.53333333333334 El máximo es de:  25.2 El mínimo es de:  12.2 .
# ['TUCUMAN AERO', 'Temperatura máxima (grados C)', '31.0', '29.7', '27.9', '24.6', '21.2', '18.6', '19.3', '22.8', '25.4', '28.9', '29.9', '30.8']
# Valor salteado
# Valor salteado
# El promedio es de:  25.84166666666667 El máximo es de:  31.0 El mínimo es de:  18.6 .
# ['TUCUMAN AERO', 'Temperatura mínima (grados C)', '20.1', '19.3', '18.5', '15.1', '11.4', '8.2', '6.8', '8.5', '11.0', '15.2', '17.5', '19.3']
# Valor salteado
# Valor salteado
# El promedio es de:  14.241666666666667 El máximo es de:  20.1 El mínimo es de:  6.8 .
# ['TUCUMAN AERO', 'Humedad relativa (%)', '74.2', '76.8', '81.0', '81.2', '80.3', '78.9', '70.9', '62.1', '58.4', '61.5', '67.1', '70.8']
# Valor salteado
# Valor salteado
# El promedio es de:  71.93333333333332 El máximo es de:  81.2 El mínimo es de:  58.4 .
# ['TUCUMAN AERO', 'Velocidad del Viento (km/h)', '11.6', '11.3', '10.0', '9.6', '9.4', '9.7', '10.7', '11.2', '11.8', '12.2', '12.0', '11.1']
# Valor salteado
# Valor salteado
# El promedio es de:  10.883333333333333 El máximo es de:  12.2 El mínimo es de:  9.4 .
# ['TUCUMAN AERO', 'Nubosidad total (octavos)', '5.0', '5.1', '5.2', '5.1', '4.7', '4.6', '3.4', '3.3', '3.5', '4.2', '4.7', '4.8']
# Valor salteado
# Valor salteado
# El promedio es de:  4.466666666666666 El máximo es de:  5.2 El mínimo es de:  3.3 .
# ['TUCUMAN AERO', 'Precipitación (mm)', '230.6', '172.3', '151.1', '62.5', '25.9', '13.1', '7.4', '8.5', '16.1', '65.1', '103.0', '175.9']
# Valor salteado
# Valor salteado
# El promedio es de:  85.95833333333333 El máximo es de:  230.6 El mínimo es de:  7.4 .
# ['TUCUMAN AERO', 'Frecuencia de días con Precipitación superior a 0.1 mm', '13.7', '11.5', '12.9', '9.6', '6.9', '5.2', '3.3', '2.1', '3.3', '7.3', '10.8', '12.1']
# Valor salteado
# Valor salteado
# El promedio es de:  8.225 El máximo es de:  13.7 El mínimo es de:  2.1 .
# ['SANTIAGO DEL ESTERO AERO', 'Temperatura (grados C)', '26.7', '25.5', '23.8', '19.8', '16.1', '12.7', '12.2', '15.3', '18.5', '22.7', '24.8', '26.5']
# Valor salteado
# Valor salteado
# El promedio es de:  20.383333333333336 El máximo es de:  26.7 El mínimo es de:  12.2 .
# ['SANTIAGO DEL ESTERO AERO', 'Temperatura máxima (grados C)', '33.9', '32.5', '30.4', '26.3', '23.1', '20.1', '20.9', '24.4', '26.9', '30.7', '32.2', '33.7']
# Valor salteado
# Valor salteado
# El promedio es de:  27.925 El máximo es de:  33.9 El mínimo es de:  20.1 .
# ['SANTIAGO DEL ESTERO AERO', 'Temperatura mínima (grados C)', '20.5', '19.7', '18.5', '14.6', '10.4', '6.8', '5.0', '7.3', '10.3', '15.3', '17.8', '20.0']
# Valor salteado
# Valor salteado
# El promedio es de:  13.850000000000001 El máximo es de:  20.5 El mínimo es de:  5.0 .
# ['SANTIAGO DEL ESTERO AERO', 'Humedad relativa (%)', '66.8', '70.0', '74.2', '76.6', '74.5', '73.2', '63.6', '54.3', '50.9', '54.8', '59.0', '62.7']
# Valor salteado
# Valor salteado
# El promedio es de:  65.05 El máximo es de:  76.6 El mínimo es de:  50.9 .
# ['SANTIAGO DEL ESTERO AERO', 'Velocidad del Viento (km/h)', '9.2', '9.2', '8.6', '7.8', '7.3', '7.1', '8.2', '9.0', '10.2', '11.6', '10.9', '10.0']
# Valor salteado
# Valor salteado
# El promedio es de:  9.091666666666667 El máximo es de:  11.6 El mínimo es de:  7.1 .
# ['SANTIAGO DEL ESTERO AERO', 'Nubosidad total (octavos)', '4.0', '4.1', '4.3', '4.5', '4.2', '4.2', '3.1', '2.9', '3.2', '3.6', '3.8', '3.9']
# Valor salteado
# Valor salteado
# El promedio es de:  3.8166666666666664 El máximo es de:  4.5 El mínimo es de:  2.9 .
# ['SANTIAGO DEL ESTERO AERO', 'Precipitación (mm)', '134.8', '100.6', '91.1', '35.9', '17.2', '6.6', '3.0', '2.0', '12.3', '44.7', '66.7', '114.2']
# Valor salteado
# Valor salteado
# El promedio es de:  52.425000000000004 El máximo es de:  134.8 El mínimo es de:  2.0 .
# ['SANTIAGO DEL ESTERO AERO', 'Frecuencia de días con Precipitación superior a 0.1 mm', '9.8', '8.7', '9.5', '7.1', '4.5', '3.9', '1.9', '1.3', '2.2', '5.9', '7.2', '8.9']
# Valor salteado
# Valor salteado
# El promedio es de:  5.908333333333334 El máximo es de:  9.8 El mínimo es de:  1.3 .
# ['RESISTENCIA AERO', 'Temperatura (grados C)', '26.8', '25.9', '24.6', '21.2', '17.6', '15.4', '14.8', '16.7', '18.5', '21.8', '23.6', '25.8']
# Valor salteado
# Valor salteado
# El promedio es de:  21.058333333333337 El máximo es de:  26.8 El mínimo es de:  14.8 .
# ['RESISTENCIA AERO', 'Temperatura máxima (grados C)', '33.3', '32.1', '30.7', '26.9', '23.6', '21.3', '21.4', '23.7', '25.3', '28.1', '29.8', '32.1']
# Valor salteado
# Valor salteado
# El promedio es de:  27.358333333333338 El máximo es de:  33.3 El mínimo es de:  21.3 .
# ['RESISTENCIA AERO', 'Temperatura mínima (grados C)', '20.9', '20.5', '19.5', '16.5', '12.6', '10.8', '9.5', '10.8', '12.4', '15.9', '17.7', '19.7']
# Valor salteado
# Valor salteado
# El promedio es de:  15.566666666666665 El máximo es de:  20.9 El mínimo es de:  9.5 .
# ['RESISTENCIA AERO', 'Humedad relativa (%)', '70.8', '74.5', '77.4', '81.0', '81.7', '82.5', '77.3', '72.5', '70.6', '71.8', '72.0', '70.8']
# Valor salteado
# Valor salteado
# El promedio es de:  75.24166666666666 El máximo es de:  82.5 El mínimo es de:  70.6 .
# ['RESISTENCIA AERO', 'Velocidad del Viento (km/h)', '10.1', '10.5', '9.9', '9.8', '9.8', '10.0', '11.2', '12.7', '13.8', '13.4', '12.5', '10.7']
# Valor salteado
# Valor salteado
# El promedio es de:  11.200000000000001 El máximo es de:  13.8 El mínimo es de:  9.8 .
# ['RESISTENCIA AERO', 'Nubosidad total (octavos)', '3.7', '3.8', '3.5', '4.1', '3.8', '4.4', '3.7', '3.6', '3.8', '3.7', '3.5', '3.6']
# Valor salteado
# Valor salteado
# El promedio es de:  3.766666666666667 El máximo es de:  4.4 El mínimo es de:  3.5 .
# ['RESISTENCIA AERO', 'Precipitación (mm)', '161.1', '165.6', '174.4', '202.3', '78.4', '63.8', '30.6', '38.0', '68.9', '134.7', '168.2', '146.9']
# Valor salteado
# Valor salteado
# El promedio es de:  119.40833333333335 El máximo es de:  202.3 El mínimo es de:  30.6 .
# ['RESISTENCIA AERO', 'Frecuencia de días con Precipitación superior a 0.1 mm', '8.9', '9.1', '9.2', '9.6', '7.1', '7.9', '5.6', '5.0', '7.6', '10.1', '10.0', '9.1']
# Valor salteado
# Valor salteado
# El promedio es de:  8.266666666666666 El máximo es de:  10.1 El mínimo es de:  5.0 .
# ['FORMOSA AERO', 'Temperatura (grados C)', '27.6', '26.8', '25.7', '22.5', '18.9', '17.0', '16.3', '18.1', '19.8', '23.0', '24.7', '26.7']
# Valor salteado
# Valor salteado
# El promedio es de:  22.258333333333336 El máximo es de:  27.6 El mínimo es de:  16.3 .
# ['FORMOSA AERO', 'Temperatura máxima (grados C)', '33.8', '32.8', '31.9', '28.1', '24.4', '22.4', '22.3', '24.8', '26.3', '29.0', '30.7', '32.8']
# Valor salteado
# Valor salteado
# El promedio es de:  28.275000000000006 El máximo es de:  33.8 El mínimo es de:  22.3 .
# ['FORMOSA AERO', 'Temperatura mínima (grados C)', '22.3', '21.9', '20.9', '18.2', '14.6', '12.9', '11.7', '13.0', '14.5', '17.9', '19.4', '21.3']
# Valor salteado
# Valor salteado
# El promedio es de:  17.383333333333336 El máximo es de:  22.3 El mínimo es de:  11.7 .
# ['FORMOSA AERO', 'Humedad relativa (%)', '71.2', '74.3', '75.9', '79.5', '80.2', '80.8', '76.5', '71.6', '70.2', '71.8', '71.4', '70.8']
# Valor salteado
# Valor salteado
# El promedio es de:  74.51666666666667 El máximo es de:  80.8 El mínimo es de:  70.2 .
# ['FORMOSA AERO', 'Velocidad del Viento (km/h)', '11.8', '11.9', '11.2', '11.5', '11.6', '11.9', '13.1', '14.4', '14.9', '14.9', '14.4', '13.0']
# Valor salteado
# Valor salteado
# El promedio es de:  12.883333333333335 El máximo es de:  14.9 El mínimo es de:  11.2 .
# ['FORMOSA AERO', 'Nubosidad total (octavos)', '3.9', '3.9', '3.6', '4.0', '3.9', '4.4', '3.8', '3.6', '3.8', '3.9', '3.6', '3.7']
# Valor salteado
# Valor salteado
# El promedio es de:  3.8416666666666672 El máximo es de:  4.4 El mínimo es de:  3.6 .
# ['FORMOSA AERO', 'Precipitación (mm)', '165.7', '128.7', '144.8', '175.0', '99.3', '68.9', '47.5', '44.2', '90.8', '142.0', '166.5', '163.4']
# Valor salteado
# Valor salteado
# El promedio es de:  119.73333333333335 El máximo es de:  175.0 El mínimo es de:  44.2 .
# ['FORMOSA AERO', 'Frecuencia de días con Precipitación superior a 0.1 mm', '9.1', '8.9', '8.5', '9.2', '7.7', '7.2', '5.5', '5.8', '7.6', '9.6', '9.1', '9.1']
# Valor salteado
# Valor salteado
# El promedio es de:  8.108333333333333 El máximo es de:  9.6 El mínimo es de:  5.5 .
# ['CORRIENTES AERO', 'Temperatura (grados C)', '27.0', '26.0', '24.7', '21.4', '18.0', '15.9', '15.2', '17.0', '18.5', '21.8', '23.7', '25.8']
# Valor salteado
# Valor salteado
# El promedio es de:  21.25 El máximo es de:  27.0 El mínimo es de:  15.2 .
# ['CORRIENTES AERO', 'Temperatura máxima (grados C)', '33.2', '31.9', '30.6', '26.8', '23.4', '21.0', '21.1', '23.4', '24.9', '27.9', '29.5', '31.9']
# Valor salteado
# Valor salteado
# El promedio es de:  27.13333333333333 El máximo es de:  33.2 El mínimo es de:  21.0 .
# ['CORRIENTES AERO', 'Temperatura mínima (grados C)', '21.3', '20.8', '19.7', '16.9', '13.4', '11.6', '10.4', '11.5', '13.1', '16.3', '17.9', '20.1']
# Valor salteado
# Valor salteado
# El promedio es de:  16.083333333333332 El máximo es de:  21.3 El mínimo es de:  10.4 .
# ['CORRIENTES AERO', 'Humedad relativa (%)', '70.7', '74.6', '77.7', '80.2', '80.0', '81.2', '76.5', '72.3', '70.8', '72.3', '72.1', '70.9']
# Valor salteado
# Valor salteado
# El promedio es de:  74.94166666666665 El máximo es de:  81.2 El mínimo es de:  70.7 .
# ['CORRIENTES AERO', 'Velocidad del Viento (km/h)', '11.9', '12.2', '11.8', '11.9', '11.9', '12.1', '13.4', '14.6', '15.5', '15.7', '14.1', '12.5']
# Valor salteado
# Valor salteado
# El promedio es de:  13.133333333333333 El máximo es de:  15.7 El mínimo es de:  11.8 .
# ['CORRIENTES AERO', 'Nubosidad total (octavos)', '3.6', '3.6', '3.3', '3.9', '3.6', '4.3', '3.5', '3.5', '3.6', '3.5', '3.3', '3.5']
# Valor salteado
# Valor salteado
# El promedio es de:  3.5999999999999996 El máximo es de:  4.3 El mínimo es de:  3.3 .
# ['CORRIENTES AERO', 'Precipitación (mm)', '167.3', '161.9', '175.1', '206.6', '91.9', '70.5', '37.5', '47.2', '75.7', '150.7', '184.3', '157.7']
# Valor salteado
# Valor salteado
# El promedio es de:  127.2 El máximo es de:  206.6 El mínimo es de:  37.5 .
# ['CORRIENTES AERO', 'Frecuencia de días con Precipitación superior a 0.1 mm', '8.5', '9.4', '8.6', '10.2', '7.5', '8.4', '6.1', '5.7', '8.1', '10.4', '10.0', '9.3']
# Valor salteado
# Valor salteado
# El promedio es de:  8.516666666666667 El máximo es de:  10.4 El mínimo es de:  5.7 .
# ['POSADAS AERO', 'Temperatura (grados C)', '27.0', '26.2', '25.1', '21.9', '18.3', '16.5', '16.1', '17.9', '19.2', '22.3', '24.2', '26.3']
# Valor salteado
# Valor salteado
# El promedio es de:  21.75 El máximo es de:  27.0 El mínimo es de:  16.1 .
# ['POSADAS AERO', 'Temperatura máxima (grados C)', '33.0', '32.1', '31.2', '27.6', '23.9', '21.9', '21.9', '24.2', '25.1', '28.3', '30.3', '32.4']
# Valor salteado
# Valor salteado
# El promedio es de:  27.65833333333333 El máximo es de:  33.0 El mínimo es de:  21.9 .
# ['POSADAS AERO', 'Temperatura mínima (grados C)', '21.8', '21.3', '20.2', '17.4', '14.0', '12.3', '11.6', '13.1', '14.3', '17.1', '18.6', '20.7']
# Valor salteado
# Valor salteado
# El promedio es de:  16.866666666666664 El máximo es de:  21.8 El mínimo es de:  11.6 .
# ['POSADAS AERO', 'Humedad relativa (%)', '68.5', '72.1', '73.0', '76.4', '77.4', '78.8', '74.7', '70.3', '69.8', '69.8', '66.9', '65.8']
# Valor salteado
# Valor salteado
# El promedio es de:  71.95833333333331 El máximo es de:  78.8 El mínimo es de:  65.8 .
# ['POSADAS AERO', 'Velocidad del Viento (km/h)', '9.1', '9.1', '8.6', '8.7', '9.0', '8.9', '10.1', '10.9', '11.0', '11.0', '10.4', '9.6']
# Valor salteado
# Valor salteado
# El promedio es de:  9.700000000000001 El máximo es de:  11.0 El mínimo es de:  8.6 .
# ['POSADAS AERO', 'Nubosidad total (octavos)', '3.6', '3.6', '3.3', '3.7', '3.6', '4.1', '3.6', '3.6', '3.8', '3.7', '3.4', '3.4']
# Valor salteado
# Valor salteado
# El promedio es de:  3.6166666666666667 El máximo es de:  4.1 El mínimo es de:  3.3 .
# ['POSADAS AERO', 'Precipitación (mm)', '167.2', '154.9', '144.1', '193.8', '138.2', '139.8', '103.3', '93.9', '145.1', '226.0', '181.0', '179.9']
# Valor salteado
# Valor salteado
# El promedio es de:  155.6 El máximo es de:  226.0 El mínimo es de:  93.9 .
# ['POSADAS AERO', 'Frecuencia de días con Precipitación superior a 0.1 mm', '10.3', '9.6', '9.0', '10.2', '8.3', '9.4', '9.0', '8.3', '10.9', '11.3', '9.5', '9.4']
# Valor salteado
# Valor salteado
# El promedio es de:  9.6 El máximo es de:  11.3 El mínimo es de:  8.3 .
# ['TINOGASTA', 'Temperatura (grados C)', '25.6', '24.4', '22.9', '18.3', '13.5', '10.3', '10.0', '13.2', '16.2', '21.3', '23.9', '25.9']
# Valor salteado
# Valor salteado
# El promedio es de:  18.791666666666668 El máximo es de:  25.9 El mínimo es de:  10.0 .
# ['TINOGASTA', 'Temperatura máxima (grados C)', '33.5', '32.4', '30.9', '26.9', '22.6', '19.9', '19.8', '23.1', '25.7', '30.2', '32.5', '33.9']
# Valor salteado
# Valor salteado
# El promedio es de:  27.616666666666664 El máximo es de:  33.9 El mínimo es de:  19.8 .
# ['TINOGASTA', 'Temperatura mínima (grados C)', '18.7', '17.3', '16.0', '10.1', '4.5', '0.8', '0.2', '2.5', '5.9', '11.2', '15.1', '17.9']
# Valor salteado
# Valor salteado
# El promedio es de:  10.016666666666666 El máximo es de:  18.7 El mínimo es de:  0.2 .
# ['TINOGASTA', 'Humedad relativa (%)', '56.9', '58.3', '60.8', '61.6', '63.2', '60.0', '55.4', '47.7', '47.3', '46.5', '48.6', '51.6']
# Valor salteado
# Valor salteado
# El promedio es de:  54.82500000000001 El máximo es de:  63.2 El mínimo es de:  46.5 .
# ['TINOGASTA', 'Velocidad del Viento (km/h)', '5.9', '5.2', '6.6', '4.2', '4.3', '4.4', '4.6', '5.9', '5.4', '6.4', '6.5', '6.2']
# Valor salteado
# Valor salteado
# El promedio es de:  5.466666666666666 El máximo es de:  6.6 El mínimo es de:  4.2 .
# ['TINOGASTA', 'Nubosidad total (octavos)', '4.3', '4.1', '3.6', '2.8', '3.0', '2.9', '2.4', '2.1', '2.3', '2.5', '3.2', '3.8']
# Valor salteado
# Valor salteado
# El promedio es de:  3.0833333333333326 El máximo es de:  4.3 El mínimo es de:  2.1 .
# ['TINOGASTA', 'Precipitación (mm)', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D']
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# El promedio es de:  3.0833333333333326 El máximo es de:  4.3 El mínimo es de:  2.1 .
# ['TINOGASTA', 'Frecuencia de días con Precipitación superior a 0.1 mm', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D']
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# El promedio es de:  3.0833333333333326 El máximo es de:  4.3 El mínimo es de:  2.1 .
# ['LA RIOJA AERO', 'Temperatura (grados C)', '27.2', '25.8', '23.9', '19.7', '15.1', '11.4', '10.8', '14.2', '17.9', '22.9', '25.5', '27.4']
# Valor salteado
# Valor salteado
# El promedio es de:  20.150000000000002 El máximo es de:  27.4 El mínimo es de:  10.8 .
# ['LA RIOJA AERO', 'Temperatura máxima (grados C)', '34.7', '33.0', '30.7', '26.7', '22.6', '19.4', '19.5', '23.0', '26.2', '30.9', '33.5', '35.1']
# Valor salteado
# Valor salteado
# El promedio es de:  27.941666666666666 El máximo es de:  35.1 El mínimo es de:  19.4 .
# ['LA RIOJA AERO', 'Temperatura mínima (grados C)', '21.1', '19.9', '18.7', '14.5', '9.7', '5.6', '4.4', '7.2', '10.9', '16.0', '18.7', '20.9']
# Valor salteado
# Valor salteado
# El promedio es de:  13.966666666666667 El máximo es de:  21.1 El mínimo es de:  4.4 .
# ['LA RIOJA AERO', 'Humedad relativa (%)', '61.8', '64.6', '68.6', '69.7', '69.7', '69.4', '62.9', '52.9', '48.9', '48.8', '51.9', '55.9']
# Valor salteado
# Valor salteado
# El promedio es de:  60.42499999999998 El máximo es de:  69.7 El mínimo es de:  48.8 .
# ['LA RIOJA AERO', 'Velocidad del Viento (km/h)', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D']
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# El promedio es de:  60.42499999999998 El máximo es de:  69.7 El mínimo es de:  48.8 .
# ['LA RIOJA AERO', 'Nubosidad total (octavos)', '3.9', '3.9', '3.9', '3.6', '3.4', '3.4', '2.6', '2.4', '2.5', '2.8', '3.2', '3.6']
# Valor salteado
# Valor salteado
# El promedio es de:  3.266666666666667 El máximo es de:  3.9 El mínimo es de:  2.4 .
# ['LA RIOJA AERO', 'Precipitación (mm)', '96.3', '73.6', '65.0', '29.3', '9.0', '2.9', '3.8', '4.2', '9.4', '17.6', '35.9', '65.0']
# Valor salteado
# Valor salteado
# El promedio es de:  34.33333333333333 El máximo es de:  96.3 El mínimo es de:  2.9 .
# ['LA RIOJA AERO', 'Frecuencia de días con Precipitación superior a 0.1 mm', '8.5', '7.4', '6.0', '3.9', '2.1', '0.9', '1.0', '0.6', '1.6', '2.3', '4.1', '6.4']
# Valor salteado
# Valor salteado
# El promedio es de:  3.733333333333333 El máximo es de:  8.5 El mínimo es de:  0.6 .
# ['CATAMARCA AERO', 'Temperatura (grados C)', '27.3', '26.0', '24.4', '20.4', '16.0', '12.0', '11.6', '15.4', '19.1', '23.6', '25.6', '27.3']
# Valor salteado
# Valor salteado
# El promedio es de:  20.724999999999998 El máximo es de:  27.3 El mínimo es de:  11.6 .
# ['CATAMARCA AERO', 'Temperatura máxima (grados C)', '34.1', '32.8', '31.2', '27.5', '23.5', '20.0', '20.2', '23.9', '26.8', '30.9', '32.7', '34.3']
# Valor salteado
# Valor salteado
# El promedio es de:  28.158333333333335 El máximo es de:  34.3 El mínimo es de:  20.0 .
# ['CATAMARCA AERO', 'Temperatura mínima (grados C)', '21.5', '20.4', '19.1', '14.7', '9.8', '5.3', '4.4', '7.7', '11.8', '16.8', '19.3', '21.2']
# Valor salteado
# Valor salteado
# El promedio es de:  14.333333333333334 El máximo es de:  21.5 El mínimo es de:  4.4 .
# ['CATAMARCA AERO', 'Humedad relativa (%)', '56.2', '59.8', '63.8', '65.3', '66.3', '66.1', '58.6', '47.7', '43.0', '44.7', '48.5', '52.5']
# Valor salteado
# Valor salteado
# El promedio es de:  56.041666666666664 El máximo es de:  66.3 El mínimo es de:  43.0 .
# ['CATAMARCA AERO', 'Velocidad del Viento (km/h)', '20.9', '18.9', '17.0', '14.2', '11.7', '9.5', '10.9', '14.8', '18.6', '22.4', '22.5', '21.9']
# Valor salteado
# Valor salteado
# El promedio es de:  16.941666666666666 El máximo es de:  22.5 El mínimo es de:  9.5 .
# ['CATAMARCA AERO', 'Nubosidad total (octavos)', '3.6', '3.6', '3.4', '3.4', '3.5', '3.5', '2.8', '2.7', '2.8', '2.9', '3.1', '3.3']
# Valor salteado
# Valor salteado
# El promedio es de:  3.216666666666667 El máximo es de:  3.6 El mínimo es de:  2.7 .
# ['CATAMARCA AERO', 'Precipitación (mm)', '83.8', '69.2', '52.4', '27.0', '12.6', '4.7', '8.1', '3.2', '7.3', '25.9', '50.2', '68.0']
# Valor salteado
# Valor salteado
# El promedio es de:  34.36666666666667 El máximo es de:  83.8 El mínimo es de:  3.2 .
# ['CATAMARCA AERO', 'Frecuencia de días con Precipitación superior a 0.1 mm', '8.9', '7.2', '7.0', '5.3', '3.3', '2.0', '2.2', '1.2', '2.2', '3.6', '5.4', '7.4']
# Valor salteado
# Valor salteado
# El promedio es de:  4.6416666666666675 El máximo es de:  8.9 El mínimo es de:  1.2 .
# ['VILLA MARIA DEL RIO SECO', 'Temperatura (grados C)', '24.0', '22.4', '21.0', '17.3', '14.0', '11.2', '10.5', '12.9', '15.3', '19.2', '21.4', '23.4']
# Valor salteado
# Valor salteado
# El promedio es de:  17.71666666666667 El máximo es de:  24.0 El mínimo es de:  10.5 .
# ['VILLA MARIA DEL RIO SECO', 'Temperatura máxima (grados C)', '31.4', '29.8', '28.1', '24.3', '21.3', '18.7', '18.7', '21.6', '23.6', '27.1', '29.1', '30.9']
# Valor salteado
# Valor salteado
# El promedio es de:  25.38333333333333 El máximo es de:  31.4 El mínimo es de:  18.7 .
# ['VILLA MARIA DEL RIO SECO', 'Temperatura mínima (grados C)', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D']
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# El promedio es de:  25.38333333333333 El máximo es de:  31.4 El mínimo es de:  18.7 .
# ['VILLA MARIA DEL RIO SECO', 'Humedad relativa (%)', '74.7', '79.7', '81.8', '82.1', '79.0', '76.7', '71.8', '66.3', '64.7', '67.5', '70.4', '72.5']
# Valor salteado
# Valor salteado
# El promedio es de:  73.93333333333332 El máximo es de:  82.1 El mínimo es de:  64.7 .
# ['VILLA MARIA DEL RIO SECO', 'Velocidad del Viento (km/h)', '6.2', '5.7', '5.2', '5.3', '5.2', '5.3', '5.7', '6.8', '7.6', '8.8', '8.6', '7.1']
# Valor salteado
# Valor salteado
# El promedio es de:  6.458333333333332 El máximo es de:  8.8 El mínimo es de:  5.2 .
# ['VILLA MARIA DEL RIO SECO', 'Nubosidad total (octavos)', '3.9', '4.1', '4.1', '4.4', '4.4', '4.2', '3.3', '3.2', '3.3', '3.6', '3.8', '4.0']
# Valor salteado
# Valor salteado
# El promedio es de:  3.858333333333333 El máximo es de:  4.4 El mínimo es de:  3.2 .
# ['VILLA MARIA DEL RIO SECO', 'Precipitación (mm)', '130.6', '119.7', '134.5', '70.4', '21.3', '8.4', '12.5', '6.7', '27.1', '62.6', '89.0', '130.2']
# Valor salteado
# Valor salteado
# El promedio es de:  67.75 El máximo es de:  134.5 El mínimo es de:  6.7 .
# ['VILLA MARIA DEL RIO SECO', 'Frecuencia de días con Precipitación superior a 0.1 mm', '9.9', '9.1', '9.4', '7.6', '4.4', '3.3', '2.7', '1.6', '3.6', '6.6', '8.7', '9.6']
# Valor salteado
# Valor salteado
# El promedio es de:  6.375 El máximo es de:  9.9 El mínimo es de:  1.6 .
# ['CERES AERO', 'Temperatura (grados C)', '25.3', '24.1', '22.6', '18.8', '15.2', '12.3', '11.5', '13.7', '16.0', '19.8', '22.2', '24.3']
# Valor salteado
# Valor salteado
# El promedio es de:  18.816666666666666 El máximo es de:  25.3 El mínimo es de:  11.5 .
# ['CERES AERO', 'Temperatura máxima (grados C)', '32.1', '30.9', '29.3', '25.0', '21.9', '18.8', '18.8', '21.7', '23.7', '27.0', '29.0', '31.0']
# Valor salteado
# Valor salteado
# El promedio es de:  25.766666666666666 El máximo es de:  32.1 El mínimo es de:  18.8 .
# ['CERES AERO', 'Temperatura mínima (grados C)', '19.2', '18.5', '17.3', '14.0', '10.3', '7.5', '6.2', '7.6', '9.5', '13.4', '15.8', '17.9']
# Valor salteado
# Valor salteado
# El promedio es de:  13.100000000000001 El máximo es de:  19.2 El mínimo es de:  6.2 .
# ['CERES AERO', 'Humedad relativa (%)', '72.0', '76.3', '78.8', '81.8', '81.7', '82.3', '78.3', '72.7', '69.6', '69.9', '70.6', '71.3']
# Valor salteado
# Valor salteado
# El promedio es de:  75.44166666666668 El máximo es de:  82.3 El mínimo es de:  69.6 .
# ['CERES AERO', 'Velocidad del Viento (km/h)', '10.2', '10.6', '10.7', '9.8', '10.3', '10.2', '12.0', '14.1', '14.6', '15.1', '13.8', '11.9']
# Valor salteado
# Valor salteado
# El promedio es de:  11.941666666666665 El máximo es de:  15.1 El mínimo es de:  9.8 .
# ['CERES AERO', 'Nubosidad total (octavos)', '3.3', '3.4', '3.4', '3.9', '4.0', '4.3', '3.5', '3.4', '3.4', '3.6', '3.3', '3.3']
# Valor salteado
# Valor salteado
# El promedio es de:  3.5666666666666664 El máximo es de:  4.3 El mínimo es de:  3.3 .
# ['CERES AERO', 'Precipitación (mm)', '132.0', '122.4', '153.5', '95.4', '35.4', '18.7', '15.6', '13.0', '36.4', '83.8', '103.2', '143.7']
# Valor salteado
# Valor salteado
# El promedio es de:  79.425 El máximo es de:  153.5 El mínimo es de:  13.0 .
# ['CERES AERO', 'Frecuencia de días con Precipitación superior a 0.1 mm', '9.4', '8.2', '9.3', '9.3', '6.0', '5.1', '3.8', '3.6', '5.1', '7.5', '9.3', '9.4']
# Valor salteado
# Valor salteado
# El promedio es de:  7.166666666666668 El máximo es de:  9.4 El mínimo es de:  3.6 .
# ['RECONQUISTA AERO', 'Temperatura (grados C)', '26.4', '25.2', '23.7', '20.0', '16.7', '14.1', '13.4', '15.4', '17.1', '20.6', '22.9', '25.0']
# Valor salteado
# Valor salteado
# El promedio es de:  20.041666666666668 El máximo es de:  26.4 El mínimo es de:  13.4 .
# ['RECONQUISTA AERO', 'Temperatura máxima (grados C)', '32.4', '30.9', '29.4', '25.4', '22.2', '19.3', '19.5', '22.2', '23.6', '26.7', '28.7', '31.0']
# Valor salteado
# Valor salteado
# El promedio es de:  25.941666666666663 El máximo es de:  32.4 El mínimo es de:  19.3 .
# ['RECONQUISTA AERO', 'Temperatura mínima (grados C)', '20.8', '20.2', '19.0', '15.7', '12.2', '9.8', '8.7', '10.0', '11.6', '15.1', '17.3', '19.5']
# Valor salteado
# Valor salteado
# El promedio es de:  14.991666666666667 El máximo es de:  20.8 El mínimo es de:  8.7 .
# ['RECONQUISTA AERO', 'Humedad relativa (%)', '70.3', '75.6', '78.0', '81.5', '81.5', '83.1', '78.8', '73.5', '71.5', '71.8', '71.0', '70.4']
# Valor salteado
# Valor salteado
# El promedio es de:  75.58333333333333 El máximo es de:  83.1 El mínimo es de:  70.3 .
# ['RECONQUISTA AERO', 'Velocidad del Viento (km/h)', '11.5', '12.0', '11.7', '10.6', '10.8', '10.7', '12.6', '14.4', '15.0', '15.5', '14.0', '12.3']
# Valor salteado
# Valor salteado
# El promedio es de:  12.591666666666669 El máximo es de:  15.5 El mínimo es de:  10.6 .
# ['RECONQUISTA AERO', 'Nubosidad total (octavos)', '3.2', '3.4', '3.2', '3.8', '3.6', '4.3', '3.5', '3.4', '3.5', '3.5', '3.2', '3.1']
# Valor salteado
# Valor salteado
# El promedio es de:  3.475000000000001 El máximo es de:  4.3 El mínimo es de:  3.1 .
# ['RECONQUISTA AERO', 'Precipitación (mm)', '141.4', '156.6', '168.3', '155.6', '58.9', '49.3', '31.2', '26.3', '53.1', '114.0', '159.8', '136.4']
# Valor salteado
# Valor salteado
# El promedio es de:  104.24166666666667 El máximo es de:  168.3 El mínimo es de:  26.3 .
# ['RECONQUISTA AERO', 'Frecuencia de días con Precipitación superior a 0.1 mm', '7.8', '8.1', '8.4', '9.2', '5.8', '5.7', '4.3', '3.8', '6.1', '8.7', '9.5', '8.7']
# Valor salteado
# Valor salteado
# El promedio es de:  7.175 El máximo es de:  9.5 El mínimo es de:  3.8 .
# ['PASO DE LOS LIBRES AERO', 'Temperatura (grados C)', '26.2', '25.0', '23.6', '19.9', '16.3', '13.9', '13.4', '15.3', '16.7', '20.1', '22.5', '25.0']
# Valor salteado
# Valor salteado
# El promedio es de:  19.825 El máximo es de:  26.2 El mínimo es de:  13.4 .
# ['PASO DE LOS LIBRES AERO', 'Temperatura máxima (grados C)', '32.6', '31.0', '29.6', '25.6', '21.9', '19.2', '19.1', '21.6', '22.6', '25.9', '28.5', '31.2']
# Valor salteado
# Valor salteado
# El promedio es de:  25.733333333333334 El máximo es de:  32.6 El mínimo es de:  19.1 .
# ['PASO DE LOS LIBRES AERO', 'Temperatura mínima (grados C)', '20.5', '20.0', '18.5', '15.2', '11.7', '9.7', '9.0', '10.3', '11.7', '14.7', '16.8', '19.0']
# Valor salteado
# Valor salteado
# El promedio es de:  14.758333333333335 El máximo es de:  20.5 El mínimo es de:  9.0 .
# ['PASO DE LOS LIBRES AERO', 'Humedad relativa (%)', '67.0', '72.5', '74.4', '78.1', '80.4', '82.3', '79.6', '75.0', '73.8', '72.2', '68.7', '65.7']
# Valor salteado
# Valor salteado
# El promedio es de:  74.14166666666667 El máximo es de:  82.3 El mínimo es de:  65.7 .
# ['PASO DE LOS LIBRES AERO', 'Velocidad del Viento (km/h)', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D']
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# El promedio es de:  74.14166666666667 El máximo es de:  82.3 El mínimo es de:  65.7 .
# ['PASO DE LOS LIBRES AERO', 'Nubosidad total (octavos)', '3.8', '3.9', '3.5', '3.9', '3.9', '4.3', '3.9', '3.8', '4.0', '3.9', '3.5', '3.6']
# Valor salteado
# Valor salteado
# El promedio es de:  3.8333333333333335 El máximo es de:  4.3 El mínimo es de:  3.5 .
# ['PASO DE LOS LIBRES AERO', 'Precipitación (mm)', '128.0', '154.3', '166.8', '205.0', '129.8', '101.4', '73.7', '56.8', '108.7', '152.6', '149.9', '120.6']
# Valor salteado
# Valor salteado
# El promedio es de:  128.96666666666667 El máximo es de:  205.0 El mínimo es de:  56.8 .
# ['PASO DE LOS LIBRES AERO', 'Frecuencia de días con Precipitación superior a 0.1 mm', '7.1', '8.5', '7.7', '8.6', '7.4', '8.0', '6.7', '5.9', '7.7', '9.1', '7.7', '6.9']
# Valor salteado
# Valor salteado
# El promedio es de:  7.608333333333333 El máximo es de:  9.1 El mínimo es de:  5.9 .
# ['SAN JUAN AERO', 'Temperatura (grados C)', '27.1', '25.5', '22.8', '17.2', '12.2', '8.3', '7.7', '10.6', '14.4', '19.8', '23.4', '26.3']
# Valor salteado
# Valor salteado
# El promedio es de:  17.94166666666667 El máximo es de:  27.1 El mínimo es de:  7.7 .
# ['SAN JUAN AERO', 'Temperatura máxima (grados C)', '34.9', '33.4', '30.3', '25.2', '20.5', '16.9', '16.5', '19.9', '23.2', '28.1', '31.6', '34.2']
# Valor salteado
# Valor salteado
# El promedio es de:  26.224999999999998 El máximo es de:  34.9 El mínimo es de:  16.5 .
# ['SAN JUAN AERO', 'Temperatura mínima (grados C)', '19.5', '18.2', '16.2', '10.7', '5.8', '1.5', '0.7', '2.9', '6.5', '11.4', '14.8', '18.0']
# Valor salteado
# Valor salteado
# El promedio es de:  10.516666666666667 El máximo es de:  19.5 El mínimo es de:  0.7 .
# ['SAN JUAN AERO', 'Humedad relativa (%)', '44.3', '47.1', '54.5', '57.9', '61.4', '62.5', '57.8', '48.2', '43.8', '39.6', '38.9', '40.1']
# Valor salteado
# Valor salteado
# El promedio es de:  49.675000000000004 El máximo es de:  62.5 El mínimo es de:  38.9 .
# ['SAN JUAN AERO', 'Velocidad del Viento (km/h)', '15.5', '13.9', '12.9', '10.6', '9.3', '9.3', '10.3', '11.6', '12.6', '14.8', '16.0', '16.1']
# Valor salteado
# Valor salteado
# El promedio es de:  12.741666666666665 El máximo es de:  16.1 El mínimo es de:  9.3 .
# ['SAN JUAN AERO', 'Nubosidad total (octavos)', '2.8', '2.7', '2.8', '2.5', '2.9', '2.9', '2.5', '2.3', '2.5', '2.3', '2.3', '2.5']
# Valor salteado
# Valor salteado
# El promedio es de:  2.5833333333333335 El máximo es de:  2.9 El mínimo es de:  2.3 .
# ['SAN JUAN AERO', 'Precipitación (mm)', '15.7', '18.9', '11.2', '4.4', '4.4', '1.6', '3.5', '3.2', '5.6', '3.6', '7.0', '11.6']
# Valor salteado
# Valor salteado
# El promedio es de:  7.558333333333333 El máximo es de:  18.9 El mínimo es de:  1.6 .
# ['SAN JUAN AERO', 'Frecuencia de días con Precipitación superior a 0.1 mm', '3.5', '2.9', '2.5', '1.3', '1.2', '0.5', '1.1', '0.9', '1.8', '1.1', '1.6', '2.3']
# Valor salteado
# Valor salteado
# El promedio es de:  1.7250000000000003 El máximo es de:  3.5 El mínimo es de:  0.5 .
# ['CHAMICAL AERO', 'Temperatura (grados C)', '26.5', '25.1', '23.2', '19.1', '15.2', '11.9', '11.3', '14.4', '17.7', '22.2', '24.6', '26.4']
# Valor salteado
# Valor salteado
# El promedio es de:  19.8 El máximo es de:  26.5 El mínimo es de:  11.3 .
# ['CHAMICAL AERO', 'Temperatura máxima (grados C)', '33.2', '31.6', '29.2', '25.2', '21.4', '18.3', '18.6', '22.0', '25.0', '29.3', '31.7', '33.5']
# Valor salteado
# Valor salteado
# El promedio es de:  26.58333333333334 El máximo es de:  33.5 El mínimo es de:  18.3 .
# ['CHAMICAL AERO', 'Temperatura mínima (grados C)', '20.3', '19.3', '18.1', '14.1', '10.0', '6.6', '5.3', '7.7', '10.6', '15.1', '17.7', '19.7']
# Valor salteado
# Valor salteado
# El promedio es de:  13.70833333333333 El máximo es de:  20.3 El mínimo es de:  5.3 .
# ['CHAMICAL AERO', 'Humedad relativa (%)', '60.0', '63.3', '67.4', '68.6', '68.7', '67.4', '60.0', '50.3', '46.5', '47.3', '50.5', '54.8']
# Valor salteado
# Valor salteado
# El promedio es de:  58.73333333333333 El máximo es de:  68.7 El mínimo es de:  46.5 .
# ['CHAMICAL AERO', 'Velocidad del Viento (km/h)', '11.7', '9.8', '8.2', '7.1', '6.6', '6.4', '7.5', '9.5', '11.3', '13.8', '14.0', '13.2']
# Valor salteado
# Valor salteado
# El promedio es de:  9.924999999999999 El máximo es de:  14.0 El mínimo es de:  6.4 .
# ['CHAMICAL AERO', 'Nubosidad total (octavos)', '3.6', '3.7', '3.9', '3.9', '3.8', '3.9', '2.9', '2.6', '2.8', '2.9', '3.2', '3.4']
# Valor salteado
# Valor salteado
# El promedio es de:  3.3833333333333333 El máximo es de:  3.9 El mínimo es de:  2.6 .
# ['CHAMICAL AERO', 'Precipitación (mm)', '105.0', '95.1', '68.2', '26.6', '9.9', '2.1', '4.9', '1.7', '9.4', '30.4', '42.6', '83.5']
# Valor salteado
# Valor salteado
# El promedio es de:  39.949999999999996 El máximo es de:  105.0 El mínimo es de:  1.7 .
# ['CHAMICAL AERO', 'Frecuencia de días con Precipitación superior a 0.1 mm', '8.6', '6.6', '6.8', '4.4', '2.7', '1.5', '1.4', '1.0', '2.2', '2.9', '5.4', '7.2']
# Valor salteado
# Valor salteado
# El promedio es de:  4.2250000000000005 El máximo es de:  8.6 El mínimo es de:  1.0 .
# ['VILLA DOLORES AERO', 'Temperatura (grados C)', '25.1', '23.7', '21.8', '17.7', '13.8', '10.7', '10.1', '12.9', '15.8', '20.3', '22.8', '24.6']
# Valor salteado
# Valor salteado
# El promedio es de:  18.275000000000002 El máximo es de:  25.1 El mínimo es de:  10.1 .
# ['VILLA DOLORES AERO', 'Temperatura máxima (grados C)', '32.3', '31.0', '28.8', '24.9', '21.1', '18.3', '18.2', '21.3', '24.0', '28.1', '30.4', '31.9']
# Valor salteado
# Valor salteado
# El promedio es de:  25.85833333333333 El máximo es de:  32.3 El mínimo es de:  18.2 .
# ['VILLA DOLORES AERO', 'Temperatura mínima (grados C)', '18.1', '17.1', '16.0', '12.2', '8.7', '5.6', '4.5', '6.6', '8.8', '12.8', '15.2', '17.3']
# Valor salteado
# Valor salteado
# El promedio es de:  11.908333333333333 El máximo es de:  18.1 El mínimo es de:  4.5 .
# ['VILLA DOLORES AERO', 'Humedad relativa (%)', '61.1', '64.9', '70.3', '71.4', '72.2', '70.5', '64.3', '54.4', '50.5', '50.7', '53.0', '57.9']
# Valor salteado
# Valor salteado
# El promedio es de:  61.76666666666667 El máximo es de:  72.2 El mínimo es de:  50.5 .
# ['VILLA DOLORES AERO', 'Velocidad del Viento (km/h)', '7.1', '5.0', '4.6', '5.0', '4.6', '4.3', '5.6', '6.5', '7.1', '8.7', '8.6', '7.3']
# Valor salteado
# Valor salteado
# El promedio es de:  6.199999999999999 El máximo es de:  8.7 El mínimo es de:  4.3 .
# ['VILLA DOLORES AERO', 'Nubosidad total (octavos)', '3.4', '3.5', '3.6', '3.5', '3.8', '3.6', '3.1', '3.0', '3.1', '3.2', '3.3', '3.5']
# Valor salteado
# Valor salteado
# El promedio es de:  3.3833333333333333 El máximo es de:  3.8 El mínimo es de:  3.0 .
# ['VILLA DOLORES AERO', 'Precipitación (mm)', '121.1', '102.2', '94.4', '42.4', '17.6', '4.7', '13.2', '6.1', '22.9', '35.1', '75.1', '113.3']
# Valor salteado
# Valor salteado
# El promedio es de:  54.00833333333333 El máximo es de:  121.1 El mínimo es de:  4.7 .
# ['VILLA DOLORES AERO', 'Frecuencia de días con Precipitación superior a 0.1 mm', '10.5', '9.1', '8.6', '5.5', '3.7', '1.8', '2.5', '1.6', '3.7', '4.8', '8.0', '10.5']
# Valor salteado
# Valor salteado
# El promedio es de:  5.858333333333334 El máximo es de:  10.5 El mínimo es de:  1.6 .
# ['CORDOBA AERO', 'Temperatura (grados C)', '23.4', '22.2', '20.7', '17.2', '13.7', '10.7', '10.0', '12.5', '14.9', '18.6', '20.9', '22.9']
# Valor salteado
# Valor salteado
# El promedio es de:  17.308333333333334 El máximo es de:  23.4 El mínimo es de:  10.0 .
# ['CORDOBA AERO', 'Temperatura máxima (grados C)', '29.4', '28.3', '26.9', '23.6', '20.5', '18.0', '17.6', '20.3', '22.3', '25.6', '27.5', '29.0']
# Valor salteado
# Valor salteado
# El promedio es de:  24.083333333333332 El máximo es de:  29.4 El mínimo es de:  17.6 .
# ['CORDOBA AERO', 'Temperatura mínima (grados C)', '17.5', '16.6', '15.5', '11.7', '8.3', '5.1', '4.0', '5.9', '8.2', '11.9', '14.4', '16.8']
# Valor salteado
# Valor salteado
# El promedio es de:  11.325000000000001 El máximo es de:  17.5 El mínimo es de:  4.0 .
# ['CORDOBA AERO', 'Humedad relativa (%)', '69.9', '73.2', '76.0', '74.4', '72.7', '70.3', '65.7', '58.3', '56.7', '60.0', '62.4', '65.9']
# Valor salteado
# Valor salteado
# El promedio es de:  67.125 El máximo es de:  76.0 El mínimo es de:  56.7 .
# ['CORDOBA AERO', 'Velocidad del Viento (km/h)', '12.6', '11.3', '11.4', '11.5', '11.2', '10.9', '12.0', '13.5', '14.8', '15.8', '15.8', '13.7']
# Valor salteado
# Valor salteado
# El promedio es de:  12.875 El máximo es de:  15.8 El mínimo es de:  10.9 .
# ['CORDOBA AERO', 'Nubosidad total (octavos)', '3.8', '3.9', '3.9', '4.0', '4.2', '4.0', '3.5', '3.3', '3.5', '3.7', '3.7', '4.0']
# Valor salteado
# Valor salteado
# El promedio es de:  3.7916666666666674 El máximo es de:  4.2 El mínimo es de:  3.3 .
# ...
# Valor salteado
# El promedio es de:  22.766666666666666 El máximo es de:  27.4 El mínimo es de:  18.6 .
# ['RIO GALLEGOS AERO', 'Nubosidad total (octavos)', '5.6', '5.2', '4.9', '4.8', '4.5', '4.3', '4.3', '4.4', '4.7', '4.8', '5.2', '5.6']
# Valor salteado
# Valor salteado
# El promedio es de:  4.858333333333333 El máximo es de:  5.6 El mínimo es de:  4.3 .
# ['RIO GALLEGOS AERO', 'Precipitación (mm)', '27.7', '27.1', '26.7', '26.7', '26.9', '18.3', '19.2', '16.9', '13.3', '16.9', '22.7', '25.9']
# Valor salteado
# Valor salteado
# El promedio es de:  22.358333333333334 El máximo es de:  27.7 El mínimo es de:  13.3 .
# ['RIO GALLEGOS AERO', 'Frecuencia de días con Precipitación superior a 0.1 mm', '10.1', '7.9', '8.7', '8.6', '8.3', '7.3', '7.4', '6.4', '6.2', '6.0', '8.0', '9.6']
# Valor salteado
# Valor salteado
# El promedio es de:  7.874999999999999 El máximo es de:  10.1 El mínimo es de:  6.0 .
# ['RIO GRANDE B.A.', 'Temperatura (grados C)', '10.9', '10.3', '8.1', '5.5', '2.6', '-0.1', '-0.2', '1.4', '3.5', '6.2', '8.4', '10.0']
# Valor salteado
# Valor salteado
# El promedio es de:  5.55 El máximo es de:  10.9 El mínimo es de:  -0.2 .
# ['RIO GRANDE B.A.', 'Temperatura máxima (grados C)', '16.1', '15.7', '13.5', '10.5', '6.5', '3.1', '3.0', '5.2', '8.3', '11.4', '13.4', '15.1']
# Valor salteado
# Valor salteado
# El promedio es de:  10.15 El máximo es de:  16.1 El mínimo es de:  3.0 .
# ['RIO GRANDE B.A.', 'Temperatura mínima (grados C)', '5.7', '5.4', '3.5', '1.6', '-0.8', '-3.2', '-3.1', '-1.7', '-0.2', '1.6', '3.3', '4.8']
# Valor salteado
# Valor salteado
# El promedio es de:  1.4083333333333334 El máximo es de:  5.7 El mínimo es de:  -3.2 .
# ['RIO GRANDE B.A.', 'Humedad relativa (%)', '72.7', '74.6', '77.8', '82.4', '86.0', '87.7', '86.5', '84.5', '79.5', '73.8', '70.0', '70.6']
# Valor salteado
# Valor salteado
# El promedio es de:  78.84166666666667 El máximo es de:  87.7 El mínimo es de:  70.0 .
# ['RIO GRANDE B.A.', 'Velocidad del Viento (km/h)', '29.1', '27.2', '25.3', '23.4', '19.8', '17.4', '18.0', '20.6', '21.9', '26.6', '28.1', '29.6']
# Valor salteado
# Valor salteado
# El promedio es de:  23.916666666666668 El máximo es de:  29.6 El mínimo es de:  17.4 .
# ['RIO GRANDE B.A.', 'Nubosidad total (octavos)', '5.5', '5.2', '4.9', '4.7', '4.4', '4.1', '4.1', '4.2', '4.5', '4.8', '5.2', '5.5']
# Valor salteado
# Valor salteado
# El promedio es de:  4.758333333333334 El máximo es de:  5.5 El mínimo es de:  4.1 .
# ['RIO GRANDE B.A.', 'Precipitación (mm)', '36.0', '29.7', '27.2', '28.8', '29.4', '26.7', '23.9', '20.7', '17.1', '18.5', '27.0', '36.0']
# Valor salteado
# Valor salteado
# El promedio es de:  26.75 El máximo es de:  36.0 El mínimo es de:  17.1 .
# ['RIO GRANDE B.A.', 'Frecuencia de días con Precipitación superior a 0.1 mm', '12.4', '10.9', '9.9', '9.8', '9.9', '8.0', '7.6', '7.6', '7.9', '7.8', '9.2', '11.3']
# Valor salteado
# Valor salteado
# El promedio es de:  9.358333333333333 El máximo es de:  12.4 El mínimo es de:  7.6 .
# ['BASE ESPERANZA', 'Temperatura (grados C)', '1.4', '0.7', '-2.3', '-6.1', '-8.2', '-10.4', '-10.5', '-9.0', '-6.5', '-4.3', '-1.1', '0.8']
# Valor salteado
# Valor salteado
# El promedio es de:  -4.625 El máximo es de:  1.4 El mínimo es de:  -10.5 .
# ['BASE ESPERANZA', 'Temperatura máxima (grados C)', '4.3', '3.7', '1.2', '-2.1', '-4.0', '-6.2', '-6.3', '-4.6', '-2.3', '-0.4', '2.1', '3.8']
# Valor salteado
# Valor salteado
# El promedio es de:  -0.9 El máximo es de:  4.3 El mínimo es de:  -6.3 .
# ['BASE ESPERANZA', 'Temperatura mínima (grados C)', '-1.2', '-2.0', '-5.6', '-9.7', '-12.1', '-14.3', '-14.8', '-13.2', '-10.4', '-8.0', '-4.2', '-1.9']
# Valor salteado
# Valor salteado
# El promedio es de:  -8.116666666666669 El máximo es de:  -1.2 El mínimo es de:  -14.8 .
# ['BASE ESPERANZA', 'Humedad relativa (%)', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D']
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# El promedio es de:  -8.116666666666669 El máximo es de:  -1.2 El mínimo es de:  -14.8 .
# ['BASE ESPERANZA', 'Velocidad del Viento (km/h)', '19.4', '23.7', '25.6', '27.1', '25.7', '27.9', '30.4', '28.5', '28.1', '29.7', '24.8', '24.1']
# Valor salteado
# Valor salteado
# El promedio es de:  26.25 El máximo es de:  30.4 El mínimo es de:  19.4 .
# ['BASE ESPERANZA', 'Nubosidad total (octavos)', '6.3', '6.1', '5.9', '5.7', '5.2', '5.1', '5.0', '5.1', '5.4', '5.7', '5.9', '6.1']
# Valor salteado
# Valor salteado
# El promedio es de:  5.625 El máximo es de:  6.3 El mínimo es de:  5.0 .
# ['BASE ESPERANZA', 'Precipitación (mm)', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D']
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# El promedio es de:  5.625 El máximo es de:  6.3 El mínimo es de:  5.0 .
# ['BASE ESPERANZA', 'Frecuencia de días con Precipitación superior a 0.1 mm', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D']
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# El promedio es de:  5.625 El máximo es de:  6.3 El mínimo es de:  5.0 .
# ['BASE ORCADAS', 'Temperatura (grados C)', '1.4', '1.4', '0.4', '-1.8', '-4.6', '-7.9', '-9.3', '-7.8', '-5.4', '-2.8', '-0.7', '0.6']
# Valor salteado
# Valor salteado
# El promedio es de:  -3.0416666666666665 El máximo es de:  1.4 El mínimo es de:  -9.3 .
# ['BASE ORCADAS', 'Temperatura máxima (grados C)', '3.4', '3.4', '2.3', '0.4', '-1.8', '-4.4', '-5.3', '-4.0', '-1.9', '0.4', '2.3', '3.0']
# Valor salteado
# Valor salteado
# El promedio es de:  -0.18333333333333335 El máximo es de:  3.4 El mínimo es de:  -5.3 .
# ['BASE ORCADAS', 'Temperatura mínima (grados C)', '-0.5', '-0.3', '-1.5', '-4.1', '-7.5', '-11.7', '-13.9', '-12.0', '-9.3', '-5.9', '-3.2', '-1.4']
# Valor salteado
# Valor salteado
# El promedio es de:  -5.941666666666667 El máximo es de:  -0.3 El mínimo es de:  -13.9 .
# ['BASE ORCADAS', 'Humedad relativa (%)', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D']
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# El promedio es de:  -5.941666666666667 El máximo es de:  -0.3 El mínimo es de:  -13.9 .
# ['BASE ORCADAS', 'Velocidad del Viento (km/h)', '19.9', '23.7', '23.9', '24.9', '24.0', '23.7', '24.2', '25.6', '24.7', '26.5', '23.6', '23.3']
# Valor salteado
# Valor salteado
# El promedio es de:  24.0 El máximo es de:  26.5 El mínimo es de:  19.9 .
# ['BASE ORCADAS', 'Nubosidad total (octavos)', '7.5', '7.4', '7.3', '7.2', '6.9', '6.4', '6.1', '6.2', '6.6', '7.0', '7.3', '7.3']
# Valor salteado
# Valor salteado
# El promedio es de:  6.933333333333333 El máximo es de:  7.5 El mínimo es de:  6.1 .
# ['BASE ORCADAS', 'Precipitación (mm)', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D']
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# El promedio es de:  6.933333333333333 El máximo es de:  7.5 El mínimo es de:  6.1 .
# ['BASE ORCADAS', 'Frecuencia de días con Precipitación superior a 0.1 mm', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D']
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# El promedio es de:  6.933333333333333 El máximo es de:  7.5 El mínimo es de:  6.1 .
# ['BASE BELGRANO II', 'Temperatura (grados C)', '-2.4', '-7.0', '-12.0', '-16.7', '-18.1', '-19.1', '-20.4', '-20.2', '-18.4', '-14.8', '-8.0', '-3.0']
# Valor salteado
# Valor salteado
# El promedio es de:  -13.341666666666667 El máximo es de:  -2.4 El mínimo es de:  -20.4 .
# ['BASE BELGRANO II', 'Temperatura máxima (grados C)', '0.7', '-3.7', '-8.8', '-13.5', '-14.6', '-15.7', '-17.1', '-16.6', '-14.9', '-11.0', '-4.1', '0.4']
# Valor salteado
# Valor salteado
# El promedio es de:  -9.908333333333331 El máximo es de:  0.7 El mínimo es de:  -17.1 .
# ['BASE BELGRANO II', 'Temperatura mínima (grados C)', '-5.9', '-10.9', '-16.1', '-20.7', '-22.0', '-23.1', '-24.5', '-24.4', '-23.0', '-19.4', '-12.3', '-6.9']
# Valor salteado
# Valor salteado
# El promedio es de:  -17.433333333333337 El máximo es de:  -5.9 El mínimo es de:  -24.5 .
# ['BASE BELGRANO II', 'Humedad relativa (%)', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D']
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# El promedio es de:  -17.433333333333337 El máximo es de:  -5.9 El mínimo es de:  -24.5 .
# ['BASE BELGRANO II', 'Velocidad del Viento (km/h)', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D']
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# El promedio es de:  -17.433333333333337 El máximo es de:  -5.9 El mínimo es de:  -24.5 .
# ['BASE BELGRANO II', 'Nubosidad total (octavos)', '5.4', '5.0', '4.7', '4.4', '4.1', '3.9', '4.2', '4.6', '4.7', '4.8', '5.0', '5.0']
# Valor salteado
# Valor salteado
# El promedio es de:  4.6499999999999995 El máximo es de:  5.4 El mínimo es de:  3.9 .
# ['BASE BELGRANO II', 'Precipitación (mm)', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D']
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# El promedio es de:  4.6499999999999995 El máximo es de:  5.4 El mínimo es de:  3.9 .
# ['BASE BELGRANO II', 'Frecuencia de días con Precipitación superior a 0.1 mm', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D']
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# El promedio es de:  4.6499999999999995 El máximo es de:  5.4 El mínimo es de:  3.9 .
# ['BASE MARAMBIO', 'Temperatura (grados C)', '-0.8', '-2.0', '-6.1', '-10.8', '-12.8', '-14.7', '-14.7', '-13.1', '-10.1', '-7.6', '-3.6', '-1.2']
# Valor salteado
# Valor salteado
# El promedio es de:  -8.124999999999998 El máximo es de:  -0.8 El mínimo es de:  -14.7 .
# ['BASE MARAMBIO', 'Temperatura máxima (grados C)', '1.6', '0.7', '-2.8', '-6.6', '-8.5', '-10.5', '-10.3', '-8.9', '-5.8', '-3.8', '-0.5', '1.3']
# Valor salteado
# Valor salteado
# El promedio es de:  -4.508333333333334 El máximo es de:  1.6 El mínimo es de:  -10.5 .
# ['BASE MARAMBIO', 'Temperatura mínima (grados C)', '-2.9', '-4.3', '-9.1', '-14.2', '-16.6', '-18.3', '-18.7', '-17.3', '-14.1', '-11.0', '-6.5', '-3.5']
# Valor salteado
# Valor salteado
# El promedio es de:  -11.375 El máximo es de:  -2.9 El mínimo es de:  -18.7 .
# ['BASE MARAMBIO', 'Humedad relativa (%)', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D']
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# El promedio es de:  -11.375 El máximo es de:  -2.9 El mínimo es de:  -18.7 .
# ['BASE MARAMBIO', 'Velocidad del Viento (km/h)', '23.7', '25.5', '28.5', '31.1', '30.5', '34.8', '34.5', '31.5', '31.9', '33.6', '28.9', '26.7']
# Valor salteado
# Valor salteado
# El promedio es de:  30.099999999999998 El máximo es de:  34.8 El mínimo es de:  23.7 .
# ['BASE MARAMBIO', 'Nubosidad total (octavos)', '6.7', '6.5', '6.1', '5.6', '4.9', '4.9', '4.8', '4.8', '5.2', '5.7', '6.2', '6.4']
# Valor salteado
# Valor salteado
# El promedio es de:  5.6499999999999995 El máximo es de:  6.7 El mínimo es de:  4.8 .
# ['BASE MARAMBIO', 'Precipitación (mm)', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D']
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# El promedio es de:  5.6499999999999995 El máximo es de:  6.7 El mínimo es de:  4.8 .
# ['BASE MARAMBIO', 'Frecuencia de días con Precipitación superior a 0.1 mm', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D']
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# El promedio es de:  5.6499999999999995 El máximo es de:  6.7 El mínimo es de:  4.8 .
# ['BASE SAN MARTIN', 'Temperatura (grados C)', '2.0', '0.9', '-1.2', '-3.3', '-5.3', '-9.3', '-11.6', '-11.5', '-8.9', '-5.9', '-2.0', '0.8']
# Valor salteado
# Valor salteado
# El promedio es de:  -4.608333333333333 El máximo es de:  2.0 El mínimo es de:  -11.6 .
# ['BASE SAN MARTIN', 'Temperatura máxima (grados C)', '4.5', '3.3', '1.3', '-0.9', '-2.3', '-5.8', '-7.3', '-6.9', '-4.6', '-2.1', '1.2', '3.4']
# Valor salteado
# Valor salteado
# El promedio es de:  -1.3500000000000005 El máximo es de:  4.5 El mínimo es de:  -7.3 .
# ['BASE SAN MARTIN', 'Temperatura mínima (grados C)', '-0.3', '-1.3', '-3.6', '-5.8', '-8.4', '-13.5', '-16.3', '-16.8', '-13.9', '-10.2', '-5.5', '-1.8']
# Valor salteado
# Valor salteado
# El promedio es de:  -8.116666666666667 El máximo es de:  -0.3 El mínimo es de:  -16.8 .
# ['BASE SAN MARTIN', 'Humedad relativa (%)', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D']
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# El promedio es de:  -8.116666666666667 El máximo es de:  -0.3 El mínimo es de:  -16.8 .
# ['BASE SAN MARTIN', 'Velocidad del Viento (km/h)', '14.6', '17.7', '22.3', '20.4', '19.3', '18.0', '17.3', '18.9', '17.5', '20.3', '19.2', '18.3']
# Valor salteado
# Valor salteado
# El promedio es de:  18.650000000000002 El máximo es de:  22.3 El mínimo es de:  14.6 .
# ['BASE SAN MARTIN', 'Nubosidad total (octavos)', '6.2', '6.5', '6.3', '6.0', '5.8', '5.2', '5.5', '5.9', '6.3', '6.4', '6.4', '6.2']
# Valor salteado
# Valor salteado
# El promedio es de:  6.058333333333334 El máximo es de:  6.5 El mínimo es de:  5.2 .
# ['BASE SAN MARTIN', 'Precipitación (mm)', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D']
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# El promedio es de:  6.058333333333334 El máximo es de:  6.5 El mínimo es de:  5.2 .
# ['BASE SAN MARTIN', 'Frecuencia de días con Precipitación superior a 0.1 mm', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D', 'S/D']
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# Valor salteado
# El promedio es de:  6.058333333333334 El máximo es de:  6.5 El mínimo es de:  5.2 .

# %%
lista = ['LA QUIACA OBS.', 'Temperatura m‡xima (grados C)', '20.1', '19.9', '19.9', '19.7', '17.3', '15.6', '15.4', '17.4', '19.2', '21.1', '21.7', '21.3']
print(max(lista))
# Out:
# Temperatura m‡xima (grados C)

# %% [markdown]
# 4. Responda a las siguientes preguntas teniendo en cuenta los datos leídos del archivo (pueden agregar más métodos a la clase **EstacionMeteorologica** si lo necesitan para responder a las preguntas):
#
#   4.1. ¿En qué mes y estación se registró la velocidad del viento más alta?
#
#   4.2. ¿En qué mes y estación se registró la humedad relativa más baja?
#
#   4.3 Realice un gráfico para comparar las temperaturas promedio anuales de todas las estaciones
#
# 5. En grupo, piensen qué pregunta pueden realizarle a los datos disponibles en el archivo y respóndanla. Debe ser una pregunta que pueda ser graficada. Pueden agregar más atributos a la clase **EstacionMeteorologica**, si así lo necesitan.
